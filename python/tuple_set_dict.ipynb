# %%
# 1
t = (10, 20, 30, 40, 50)
print(t[0])
# Out:
# 10

# %%
# 2
names = ("Akshay", "Rahul", "Priya", "Sneha", "Arjun")
print(names[-1])
# Out:
# Arjun

# %%
# 3
t = (10, 20, 30, 40)
print(len(t))
# Out:
# 4

# %%
# 4
countries = ("India", "USA", "UK", "Japan", "China")
print("India" in countries)
# Out:
# True

# %%
# 6
t = (1, 5, 2, 5, 3)
print(t.count(5))
# Out:
# 2

# %%
# 7
t1 = (1, 2)
t2 = (3, 4)
print(t1 + t2)
# Out:
# (1, 2, 3, 4)

# %%
# 8
animals = ("zebra", "ant", "cat", "dog")
print(sorted(animals))
# Out:
# ['ant', 'cat', 'dog', 'zebra']

# %%
# 9
t = ("Python", "Java", "C++")
print(t.index("Java"))
# Out:
# 1

# %%
# 10
t = (10, 20, 30)
print(list(t))
# Out:
# [10, 20, 30]

# %%
#SET

# %%
# 11
s = {10, 20, 30, 40, 50}
print(s)
# Out:
# {50, 20, 40, 10, 30}

# %%
# 12
s = {"Mumbai", "Chennai"}
s.add("Delhi")
print(s)
# Out:
# {'Chennai', 'Delhi', 'Mumbai'}

# %%
# 13
s = {"Maths", "Science", "English"}
s.remove("Science")
print(s)
# Out:
# {'Maths', 'English'}

# %%
# 14
s = {10, 20, 30, 40, 50}
print(50 in s)
# Out:
# True

# %%
# 15
s1 = {1, 2, 3}
s2 = {3, 4, 5}
print(s1.union(s2))
# Out:
# {1, 2, 3, 4, 5}

# %%
# 16
s1 = {1, 2, 3}
s2 = {2, 3, 4}
print(s1.intersection(s2))
# Out:
# {2, 3}

# %%
# 17
s = {"Apple", "Samsung", "OnePlus"}
print(len(s))
# Out:
# 3

# %%
# 18
s = {1, 2, 3}
s.clear()
print(s)
# Out:
# set()

# %%
# 19
s = {10, 20, 30}
s.update([40, 50])
print(s)
# Out:
# {40, 10, 50, 20, 30}

# %%
# 20
my_list = [1, 2, 2, 3, 3, 4]
print(set(my_list))
# Out:
# {1, 2, 3, 4}

# %%
#DICTIONARY

# %%
# 21
d = {"name": "Akshay", "age": 21}
print(d["name"])
print(d["age"])
# Out:
# Akshay
# 21

# %%
# 22
student = {"name": "Akshay", "grade": "A", "age": 21}
print(student["name"])
# Out:
# Akshay

# %%
# 23
d = {"Maths": 90, "Science": 85, "English": 88}
print(list(d.keys()))
# Out:
# ['Maths', 'Science', 'English']

# %%
# 24
d = {"name": "Akshay"}
d["city"] = "Abu Dhabi"
print(d)
# Out:
# {'name': 'Akshay', 'city': 'Abu Dhabi'}

# %%
# 25
d = {"a": 10, "b": 20}
d["b"] = 50
print(d)
# Out:
# {'a': 10, 'b': 50}

# %%
# 26
d = {"name": "Akshay", "age": 21}
d.pop("age")
print(d)
# Out:
# {'name': 'Akshay'}

# %%
 # 27
d = {"name": "Akshay", "role": "Engineer", "salary": 50000}
print(list(d.values()))
# Out:
# ['Akshay', 'Engineer', 50000]

# %%
# 28
d = {"name": "Akshay", "age": 21}
print("salary" in d)
# Out:
# False

# %%
# 29
d1 = {"a": 1}
d2 = {"b": 2}
d1.update(d2)
print(d1)
# Out:
# {'a': 1, 'b': 2}

# %%
# 30
d = {"name": "Akshay", "age": 21, "city": "Abu Dhabi"}
print(len(d))
# Out:
# 3

# %%
#MIXED

# %%
# 31
colors = ["red", "blue", "red", "green", "blue", "red", "yellow"]

print(sorted(colors, key=colors.count, reverse=True))
# Out:
# ['red', 'red', 'red', 'blue', 'blue', 'green', 'yellow']

# %%
# 32
numbers = [5, 2, 5, 1, 2, 5, 3]

print(sorted(numbers, key=numbers.count, reverse=True))
# Out:
# [5, 5, 5, 2, 2, 1, 3]

# %%
# 33
text = "    Python Programming    "
print(text.strip().upper())
# Out:
# PYTHON PROGRAMMING

# %%
# 34
text = "Python   Programming   Language"
print(" ".join(text.split()))
# Out:
# Python Programming Language

# %%
# 36
names = ["John", "alice", "David", "bob", "Emma"]
names.sort(key=str.lower)
print(names)
# Out:
# ['alice', 'bob', 'David', 'Emma', 'John']

# %%
# 37
numbers = [-10, 5, -2, 8, -15]
numbers.sort(key=abs)
print(numbers)
# Out:
# [-2, 5, 8, -10, -15]

# %%
# 38
text = "banana"
print("".join(sorted(text)))
# Out:
# aaabnn

# %%
# 39
text = "python programming"
print(text.replace(" ", ""))
# Out:
# pythonprogramming

# %%
# 40
text = "Python Programming Language"
print(text.count(" "))
# Out:
# 2

# %%
# 41
text = "apple,banana,orange,mango"
print(text.split(","))
# Out:
# ['apple', 'banana', 'orange', 'mango']

# %%
# 42
words = ["Python", "Java", "C++", "JavaScript"]
print(" | ".join(words))
# Out:
# Python | Java | C++ | JavaScript

# %%
# 43
numbers = [10, 20, 20, 30, 40, 40, 40]

print(sorted(numbers, key=numbers.count, reverse=True)[0])
# Out:
# 40

# %%
# 44
words = ["cat", "apple", "dog", "elephant", "ant"]
words.sort(key=len, reverse=True)
print(words)
# Out:
# ['elephant', 'apple', 'cat', 'dog', 'ant']

# %%
# 45
cities = ["Delhi", "Mumbai", "Pune", "Chennai", "Goa"]
cities.sort(key=len)
print(cities)
# Out:
# ['Goa', 'Pune', 'Delhi', 'Mumbai', 'Chennai']

# %%
# 46
numbers = [123, 45, 6789, 1, 56]
numbers.sort(key=lambda x: len(str(x)))
print(numbers)
# Out:
# [1, 45, 56, 123, 6789]

# %%
# 47
text = "Welcome To Python"
print(text.lower().replace(" ", "_"))
# Out:
# welcome_to_python

# %%
# 48
colors = ["red", "blue", "red", "green", "blue", "yellow"]
color_count = {}
for c in colors:
    color_count[c] = colors.count(c)
print(color_count)
# Out:
# {'red': 2, 'blue': 2, 'green': 1, 'yellow': 1}

# %%
# 49
numbers = [42, 35, 18, 91, 27, 63]
numbers.sort(key=lambda x: x % 10)
print(numbers)
# Out:
# [91, 42, 63, 35, 27, 18]

# %%
# 50
names = ["John", "Emma", "Alice", "David", "Bob"]
names.sort(key=lambda x: x[1])
print(names)
# Out:
# ['David', 'Alice', 'Emma', 'John', 'Bob']

# %%
# 51
words = ["apple", "banana", "apple", "orange", "banana", "grapes"]
print(sorted(set(words)))
# Out:
# ['apple', 'banana', 'grapes', 'orange']

# %%
# 52
words = ["red", "blue", "red", "green", "red", "blue"]
print(max(words, key=words.count))
# Out:
# red

# %%
# 53
text = "   Python   Programming   Language   "
print(" ".join(text.split()).title())
# Out:
# Python Programming Language

# %%
# 54
colors = ["yellow", "yellow", "red", "red", "red", "blue", "blue", "blue"]
color_count = {}
for c in set(colors):
    color_count[c] = colors.count(c)
print(color_count)
# Out:
# {'yellow': 2, 'red': 3, 'blue': 3}
