# %%
# 1
subjects = ["Maths", "Science", "English", "History", "Python"]
print(subjects[0])
# Out:
# Maths

# %%
# 2
numbers = [10, 20, 30, 40, 50]
print(numbers[-1])
# Out:
# 50

# %%
# 3
brands = ["Samsung", "Apple", "OnePlus", "Nokia"]
brands.append("Realme")
print(brands)
# Out:
# ['Samsung', 'Apple', 'OnePlus', 'Nokia', 'Realme']

# %%
# 4
students = ["Akshay", "Rahul", "Priya", "Sneha", "Arjun"]
print(len(students))
# Out:
# 5

# %%
# 5
numbers = [10, 20, 30, 40]
numbers[2] = 35
print(numbers)
# Out:
# [10, 20, 35, 40]

# %%
# 6
subjects = ["Science", "Maths", "English"]
subjects.remove("Maths")
print(subjects)
# Out:
# ['Science', 'English']

# %%
# 7
numbers = [5, 3, 9, 1, 7]
print(max(numbers))
# Out:
# 9

# %%
# 8
cities = ["Dubai", "Mumbai", "Abu Dhabi", "Delhi", "Kochi"]
cities.sort()
print(cities)
# Out:
# ['Abu Dhabi', 'Delhi', 'Dubai', 'Kochi', 'Mumbai']

# %%
# 9
list1 = [1, 2, 3]
list2 = [4, 5, 6]
combined = list1 + list2
print(combined)
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# 10
items = ["book", "pen", "pencil"]
if "pen" in items:
    print("Yes, pen is found!")
# Out:
# Yes, pen is found!
