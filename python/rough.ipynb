# %%
# 1 - Store your name 
name = "Akshay"
print(name.upper())
# Out:
# AKSHAY

# %%
# 2
sentence = "Hello Python"
print(sentence[0])
print(sentence[-1])
# Out:
# H
# n

# %%
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(a)
#
# NameError: name 'a' is not defined

# %%
a.append(4)

# %%
print(a)
# Out:
# [1, 3, 2, 4]

# %%
a.extend([5,6,7])
a
# Out:
# [1, 3, 2, 4, 5, 6, 7]

# %%
# 3
brands = ["Samsung", "Apple", "OnePlus", "Nokia"]
brands.append("Realme")
brands
# Out:
# ['Samsung', 'Apple', 'OnePlus', 'Nokia', 'Realme']

# %%
b=['a','b','c','d']

# %%
a.extend(b)
print(a)
# Out:
# [1, 3, 2, 4, 5, 6, 7, 'a', 'b', 'c', 'd']

# %%
a[1]=10
a
# Out:
# [1, 10, 2, 4, 5, 6, 7, 'a', 'b', 'c', 'd']

# %%
a.pop(8)
a
# Out:
# [1, 10, 2, 4, 5, 6, 7, 'a', 'c', 'd']

# %%
a.remove(4)
a
# Out:
# [1, 10, 2, 5, 6, 7, 'a', 'c', 'd']

# %%
a[6:]=[8,9]
a
# Out:
# [1, 10, 2, 5, 6, 7, 8, 9]

# %%
c=[1,2,3,4,5,5,5,3,1,1,1]
c
# Out:
# [1, 2, 3, 4, 5, 5, 5, 3, 1, 1, 1]

# %%
c.sort(key=c.count)
c
# Out:
# [1, 2, 3, 4, 5, 5, 5, 3, 1, 1, 1]

# %%
c.sort(key=c.count)

# %%
c
# Out:
# [1, 2, 3, 4, 5, 5, 5, 3, 1, 1, 1]

# %%
c.sort()
c
# Out:
# [1, 1, 1, 1, 2, 3, 3, 4, 5, 5, 5]

# %%
c.sort(reverse=True)
c
# Out:
# [5, 5, 5, 4, 3, 3, 2, 1, 1, 1, 1]

# %%
c.sort(key=lambda x:c.count(x))
c
# Out:
# [5, 5, 5, 4, 3, 3, 2, 1, 1, 1, 1]

# %%
d=['apple','bannana','cofffe','dd']
d.sort(key=len)
d
# Out:
# ['dd', 'apple', 'cofffe', 'bannana']

# %%
d.sort(key=len,reverse=True)
d
# Out:
# ['bannana', 'cofffe', 'apple', 'dd']

# %%
a=(1,'a',2)
type(a)
# Out:
# tuple

# %%
a.index('a')
# Out:
# 1

# %%
a.count(2)
# Out:
# 1

# %%
b=set()

# %%
b.add(1)

# %%
b.add('aaaa')

# %%
b.update(['bb','ab'])
b
# Out:
# {1, 'aaaa', 'ab', 'bb'}

# %%
b.remove(1)
b
# Out:
# {'aaaa', 'ab', 'bb'}

# %%
c={1:'akshay',2:'bbbb'}
c
# Out:
# {1: 'akshay', 2: 'bbbb'}

# %%
c[2]
# Out:
# 'bbbb'

# %%
c.update({3:'nnnn'})
c
# Out:
# {1: 'akshay', 2: 'bbbb', 3: 'nnnn'}

# %%
c.keys()
# Out:
# dict_keys([1, 2, 3])

# %%
c.values()
# Out:
# dict_values(['akshay', 'bbbb', 'nnnn'])

# %%
a=['red','white','orange']

# %%
d={'red':len('red'),'white':len(a[1]),'orange':len(a[2])}
d
# Out:
# {'red': 3, 'white': 5, 'orange': 6}

# %%
e=[100000000,200,1]
e.sort(key=lambda x:len(str(x)))
e
# Out:
# [1, 200, 100000000]

# %%
54
colors = ["yellow", "yellow", "red", "red", "red", "blue", "blue", "blue"]
a={"yellow":colors.count('yellow'),"red":colors.count("red"),'blue':colors.count('blue')}
a
# Out:
# {'yellow': 2, 'red': 3, 'blue': 3}

# %%
#1/08/26

# %%
a=3
if a %2==0:
    print("even number")
else :
    print('odd number')
# Out:
# odd number

# %%
b=int(input('enter a number'))
if b >0:
    print('postive numb')
# Out:
# postive numb

# %%
c=int(input('enter a number'))
if c==1:
    print('monday')
elif c==2:
    print('tuesday')
elif c==3:
    print('wednesday')
elif c==4:
    print('thrusday')
elif c==5:
    print('friday')
elif c==6:
    print('saturday')
elif c==7:
    print('Sunday')
else :
    print('invalid')
# Out:
# invalid

# %%
d=input('enter no')
if d.isupper():
    print('uppercase')
elif d.islower():
    print('lowercase')
elif d.isdigit():
    print('digit')
else :
    print('should be a special character')
# Out:
# should be a special character

# %%
a=float(input('enter no 1'))
b=float(input('enter no 2'))
c=input('enter a operator')
if c=='+':
 print(a+b)
elif c=='-':
 print('a-b')
elif c=='*':
 print('a*b')
elif c=='/':
 if b!=0:
  print(a/b)
 else:
  print('cannot be divided by zero')
else:
 print('Error')
# Out:
# 1.6666666666666667
